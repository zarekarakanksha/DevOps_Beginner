# %% [markdown]
# <a href="https://colab.research.google.com/github/zarekarakanksha/DevOps_Beginner/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile requirements.txt
# phidata
# python-dotenv
# yfinance
# packaging
# duckduckgo-search
# fastapi
# uvicorn
# groq
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt

# %%
import os
from google.colab import userdata

# Load the keys securely from the Colab Secrets vault
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
os.environ["PHI_API_KEY"] = userdata.get('PHI_API_KEY')

print("✅ Keys loaded successfully from secure storage!")
# Out:
# ✅ Keys loaded successfully from secure storage!

# %%
# %%writefile financial_agent.py
import os
from phi.agent import Agent
from phi.model.groq import Groq
from phi.tools.duckduckgo import DuckDuckGo
from phi.tools.yfinance import YFinanceTools
from IPython.core.display import Markdown

web_search_agent = Agent(
    name="Web Search Agent",
    role="Search the web for latest financial news and information",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[DuckDuckGo()],
    instructions=["Always include sources in your response"],
    show_tool_calls=True,
    Markdown= True,
)

finance_agent = Agent(
    name="Finance AI Agent",
    role="Analyze stocks and provide financial recommendations",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[YFinanceTools(stock_price=True, analyst_recommendations=True, company_info=True, company_news=True)],
    instructions=["Use tables to display data"],
    show_tool_calls=True,
    Markdown = True,
)

multi_agent = Agent(
    name="Financial Assistant",
    team=[web_search_agent, finance_agent],
    model=Groq(id="llama-3.3-70b-versatile"),
    instructions=[
        "Combine web information with financial data",
        "Provide comprehensive analysis",
        "Present information in a clear, structured format",
        "Always include sources"
    ],
    show_tool_calls=True,
    Markdown=True,
)
if __name__ == "__main__":
    # This block executes ONLY when running this script directly
    multi_agent.print_response("Summarize analyst recommendations and latest news for Infosys", markdown=True)
# Out:
# Overwriting financial_agent.py

# %%
# !python financial_agent.py
# Out:
# /usr/local/lib/python3.12/dist-packages/phi/tools/duckduckgo.py:86:
# ...
# Use `pip install ddgs` instead.
#   ddgs = DDGS(
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Summarize analyst recommendations and latest news for Infosys                ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (7.0s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Running:                                                                     ┃
# ┃                                                                              ┃
# ┃  • transfer_task_to_finance_ai_agent(additional_information=Provide a list   ┃
# ...
